# %%
import pandas as pd
import numpy as np
import hypertools as hyp
import seaborn as sns
from timeit import default_timer as timer
import os
import altair as alt


# %matplotlib inline

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
cdr = pd.read_csv('/home/matheus/test/cdr/FinalRound_R4_S4_L001_R1_001aafreq.csv').sort_values(by='quantity', ascending=False)

# %%
cdr.head()
# Out:
#           cdr3  quantity  length         MW      AV      IP    flex   gravy  \
# 0       FIVESK    151712       6   721.8413  0.1667  6.0014  0.7368  0.5500
# 1  DRITGTIIGNY     26378      11  1222.3474  0.0909  5.8356  0.7335 -0.1364
# 6       FLVESK     23657       6   721.8413  0.1667  6.0014  0.7423  0.4333
# 2     DLGIPDDY     22421       8   906.9324  0.1250  3.4228  0.7723 -0.6875
# 4    DLHWGAADY     16192       9  1047.0772  0.2222  4.1967  0.7286 -0.6000
#
#    SSF_Helix  SSF_Turn  ...  n_T  n_V  n_W  n_Y  aliphatic  aromatic  neutral  \
# 0     0.5000    0.1667  ...    0    1    0    0          2         1        1
# 1     0.3636    0.2727  ...    2    0    0    1          5         1        3
# 6     0.5000    0.1667  ...    0    1    0    0          2         1        1
# 2     0.3750    0.2500  ...    0    0    0    1          4         1        0
# 4     0.3333    0.1111  ...    0    0    1    1          4         2        0
#
#    positive  negative  invalid
# 0         1         1        0
# 1         1         1        0
# 6         1         1        0
# 2         0         3        0
# 4         1         2        0
#
# [5 rows x 37 columns]

# %%
c = cdr.iloc[:1000]

# %%
c.head()
# Out:
#           cdr3  quantity  length         MW      AV      IP    flex   gravy  \
# 0       FIVESK    151712       6   721.8413  0.1667  6.0014  0.7368  0.5500
# 1  DRITGTIIGNY     26378      11  1222.3474  0.0909  5.8356  0.7335 -0.1364
# 6       FLVESK     23657       6   721.8413  0.1667  6.0014  0.7423  0.4333
# 2     DLGIPDDY     22421       8   906.9324  0.1250  3.4228  0.7723 -0.6875
# 4    DLHWGAADY     16192       9  1047.0772  0.2222  4.1967  0.7286 -0.6000
#
#    SSF_Helix  SSF_Turn  ...  n_T  n_V  n_W  n_Y  aliphatic  aromatic  neutral  \
# 0     0.5000    0.1667  ...    0    1    0    0          2         1        1
# 1     0.3636    0.2727  ...    2    0    0    1          5         1        3
# 6     0.5000    0.1667  ...    0    1    0    0          2         1        1
# 2     0.3750    0.2500  ...    0    0    0    1          4         1        0
# 4     0.3333    0.1111  ...    0    0    1    1          4         2        0
#
#    positive  negative  invalid
# 0         1         1        0
# 1         1         1        0
# 6         1         1        0
# 2         0         3        0
# 4         1         2        0
#
# [5 rows x 37 columns]

# %%
alt.Chart(c).mark_point().encode(
    x=alt.X('length'),
    y=alt.Y('quantity')
)
# Out:
# <VegaLite 3 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
sequence = c.pop('cdr3')

# %%
cluster_labels = hyp.cluster(c, n_clusters=10)

# %%
hyp.plot(c, '.', reduce='TSNE', ndims=3, group=cluster_labels, legend=None, title='FinalRound_R4_S4_L001_R1_001aafreq')

# %%
hyp.plot(c, '.', reduce='TSNE', ndims=2, group=cluster_labels, legend=None, title='FinalRound_R4_S4_L001_R1_001aafreq');

# %%
ccv = hyp.cluster(c, cluster='HDBSCAN')

# %%
hyp.plot(c, '.', reduce='TSNE', ndims=3, group=ccv, legend=None, title='FinalRound_R4_S4_L001_R1_001aafreq');
