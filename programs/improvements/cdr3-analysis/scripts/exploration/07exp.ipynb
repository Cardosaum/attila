# %%
import numpy as np
import pandas as pd
from plotnine import *

# %%
f = pd.read_csv("../../../../../../data/analysis/attila_cdr/Final_wHAIPI009594-32_1aafreq.csv")

# %%
f.head()
# Out:
#         cdr3  quantity  length         MW      AV      IP    flex   gravy  \
# 0     FIVESK     83577       6   721.8413  0.1667  6.0014  0.7368  0.5500
# 1   DLGIPDDY     57780       8   906.9324  0.1250  3.4228  0.7723 -0.6875
# 2    EMWGPEY     30588       7   910.9889  0.2857  3.7950  0.7594 -1.3286
# 3    EMWGPDY     18892       7   896.9623  0.2857  3.6660  0.7563 -1.3286
# 4  DLHWGAADY     18675       9  1047.0772  0.2222  4.1967  0.7286 -0.6000
#
#    SSF_Helix  SSF_Turn  ...  n_T  n_V  n_W  n_Y  aliphatic  aromatic  neutral  \
# 0     0.5000    0.1667  ...    0    1    0    0          2         1        1
# 1     0.3750    0.2500  ...    0    0    0    1          4         1        0
# 2     0.2857    0.2857  ...    0    0    1    1          3         2        0
# 3     0.2857    0.2857  ...    0    0    1    1          3         2        0
# 4     0.3333    0.1111  ...    0    0    1    1          4         2        0
#
#    positive  negative  invalid
# ...

# %%
a = f.iloc[:50]
a.head()
# Out:
#         cdr3  quantity  length         MW      AV      IP    flex   gravy  \
# 0     FIVESK     83577       6   721.8413  0.1667  6.0014  0.7368  0.5500
# 1   DLGIPDDY     57780       8   906.9324  0.1250  3.4228  0.7723 -0.6875
# 2    EMWGPEY     30588       7   910.9889  0.2857  3.7950  0.7594 -1.3286
# 3    EMWGPDY     18892       7   896.9623  0.2857  3.6660  0.7563 -1.3286
# 4  DLHWGAADY     18675       9  1047.0772  0.2222  4.1967  0.7286 -0.6000
#
#    SSF_Helix  SSF_Turn  ...  n_T  n_V  n_W  n_Y  aliphatic  aromatic  neutral  \
# 0     0.5000    0.1667  ...    0    1    0    0          2         1        1
# 1     0.3750    0.2500  ...    0    0    0    1          4         1        0
# 2     0.2857    0.2857  ...    0    0    1    1          3         2        0
# 3     0.2857    0.2857  ...    0    0    1    1          3         2        0
# 4     0.3333    0.1111  ...    0    0    1    1          4         2        0
#
#    positive  negative  invalid
# ...

# %%
p = (ggplot(a, aes('length', 'MW')))
p + geom_point()
# Out:
# <ggplot: (8793858553233)>

# %%
fp = (ggplot(f, aes('length', 'MW')))
fp + geom_point()
# Out:
# <ggplot: (8793857443325)>

# %%
qt = (ggplot(a, aes('quantity'))) 
qt + geom_histogram()
# Out:
# /home/matheus/anaconda3/lib/python3.7/site-packages/plotnine/stats/stat_bin.py:93: PlotnineWarning: 'stat_bin()' using 'bins = 53'. Pick better value with 'binwidth'.
#   warn(msg.format(params['bins']), PlotnineWarning)
# <ggplot: (8793857368165)>

# %%
qt = (ggplot(a, aes('quantity'))) 
qt + geom_density()
# Out:
# <ggplot: (8793857368129)>

# %%
top = f.iloc[:10]
top.head()
# Out:
#         cdr3  quantity  length         MW      AV      IP    flex   gravy  \
# 0     FIVESK     83577       6   721.8413  0.1667  6.0014  0.7368  0.5500
# 1   DLGIPDDY     57780       8   906.9324  0.1250  3.4228  0.7723 -0.6875
# 2    EMWGPEY     30588       7   910.9889  0.2857  3.7950  0.7594 -1.3286
# 3    EMWGPDY     18892       7   896.9623  0.2857  3.6660  0.7563 -1.3286
# 4  DLHWGAADY     18675       9  1047.0772  0.2222  4.1967  0.7286 -0.6000
#
#    SSF_Helix  SSF_Turn  ...  n_T  n_V  n_W  n_Y  aliphatic  aromatic  neutral  \
# 0     0.5000    0.1667  ...    0    1    0    0          2         1        1
# 1     0.3750    0.2500  ...    0    0    0    1          4         1        0
# 2     0.2857    0.2857  ...    0    0    1    1          3         2        0
# 3     0.2857    0.2857  ...    0    0    1    1          3         2        0
# 4     0.3333    0.1111  ...    0    0    1    1          4         2        0
#
#    positive  negative  invalid
# ...

# %%
top.describe()
# Out:
#            quantity     length           MW         AV         IP       flex  \
# count     10.000000  10.000000    10.000000  10.000000  10.000000  10.000000
# mean   26933.700000   7.000000   852.505640   0.284450   4.413260   0.737780
# std    24621.855179   2.581989   298.022161   0.259274   1.013221   0.062264
# min     8475.000000   1.000000   181.188500   0.125000   3.422800   0.567000
# 25%    12303.250000   6.250000   761.605175   0.166700   3.795000   0.738175
# 50%    17259.500000   7.000000   892.921450   0.202000   3.864950   0.757850
# 75%    27664.000000   8.000000   909.974775   0.285700   5.192475   0.769650
# max    83577.000000  11.000000  1368.447100   1.000000   6.001400   0.779500
#
#            gravy  SSF_Helix   SSF_Turn  SSF_Sheet  ...        n_T        n_V  \
# count  10.000000  10.000000  10.000000  10.000000  ...  10.000000  10.000000
# mean   -0.846250   0.417900   0.223340   0.214010  ...   0.200000   0.300000
# ...

# %%
(ggplot(top, aes('aromatic', 'quantity'))) + geom_point()
# Out:
# <ggplot: (8793849648081)>
