# %%
import pathlib
import pandas as pd
import altair as alt

# %%
p = '/home/matheus/mcs/study/code/bioinfo/data/analysis'

a = pathlib.Path(p).rglob('*aafreq*')
n=0
for f in sorted(list(a)):
    if 'VH' in str(f) and 'isaura_2' in str(f).lower():
        print(f)
        n+=1
        
print(n)
# Out:
# /home/matheus/mcs/study/code/bioinfo/data/analysis/array3/mariajac/isaura_2/2_isaura_H_0eX4g_L_0aX4c/VH/FinalRound/VHR42g_S13_L001_R1_001aafreq.txt
# /home/matheus/mcs/study/code/bioinfo/data/analysis/array3/mariajac/isaura_2/2_isaura_H_0eX4g_L_0aX4c/VH/InitialRound/VHR02e_S12_L001_R1_001aafreq.txt
# /home/matheus/mcs/study/code/bioinfo/data/analysis/array3/mariajac/isaura_2/2_isaura_H_0eX4g_L_0aX4d/VH/FinalRound/VHR42g_S13_L001_R1_001aafreq.txt
# /home/matheus/mcs/study/code/bioinfo/data/analysis/array3/mariajac/isaura_2/2_isaura_H_0eX4g_L_0aX4d/VH/InitialRound/VHR02e_S12_L001_R1_001aafreq.txt
# /home/matheus/mcs/study/code/bioinfo/data/analysis/array3/mariajac/isaura_2/2_isaura_H_0eX4g_L_0bX4c/VH/FinalRound/VHR42g_S13_L001_R1_001aafreq.txt
# /home/matheus/mcs/study/code/bioinfo/data/analysis/array3/mariajac/isaura_2/2_isaura_H_0eX4g_L_0bX4c/VH/FinalRound/VLR42c_S10_L001_R1_001aafreq.txt
# ...

# %%
p = '/home/matheus/mcs/study/code/bioinfo/data/analysis'

a = pathlib.Path(p).rglob('*aafreq*')
n = 0 
for f in sorted(list(a)):
    if 'VH' in str(f) and 'isaura_1' in str(f).lower():
        print(f)
        n += 1
        
print(n)
# Out:
# /home/matheus/mcs/study/code/bioinfo/data/analysis/array3/mariajac/anteriores/isaura_1/isaura_HR01eXHR41g_LR01aXLR41c/VH/FinalRound/VHR41g_S6_L001_R1_001aafreq.txt
# /home/matheus/mcs/study/code/bioinfo/data/analysis/array3/mariajac/anteriores/isaura_1/isaura_HR01eXHR41g_LR01aXLR41c/VH/InitialRound/VHR01e_S5_L001_R1_001aafreq.txt
# /home/matheus/mcs/study/code/bioinfo/data/analysis/array3/mariajac/anteriores/isaura_1/isaura_HR01eXHR41g_LR01aXLR41d/VH/FinalRound/VHR41g_S6_L001_R1_001aafreq.txt
# /home/matheus/mcs/study/code/bioinfo/data/analysis/array3/mariajac/anteriores/isaura_1/isaura_HR01eXHR41g_LR01aXLR41d/VH/InitialRound/VHR01e_S5_L001_R1_001aafreq.txt
# /home/matheus/mcs/study/code/bioinfo/data/analysis/array3/mariajac/anteriores/isaura_1/isaura_HR01eXHR41g_LR01bXLR41c/VH/FinalRound/VHR41g_S6_L001_R1_001aafreq.txt
# ...

# %%
for f in a:
    if 'VH' in f:
        print(f)

# %%
type(a)
# Out:
# generator

# %%
b = '''t
array3/mariajac/isaura_2/2_isaura_H_0eX4g_L_0aX4d/VH/InitialRound/VHR02e_S12_L001_R1_001aafreq.txt
array3/mariajac/isaura_2/2_isaura_H_0eX4g_L_0bX4c/VH/InitialRound/VHR02e_S12_L001_R1_001aafreq.txt
array3/mariajac/isaura_2/2_isaura_H_0eX4g_L_0bX4c_2/VH/InitialRound/VHR02e_S12_L001_R1_001aafreq.txt
array3/mariajac/isaura_2/2_isaura_H_0eX4g_L_0bX4d/VH/InitialRound/VHR02e_S12_L001_R1_001aafreq.txt
array3/mariajac/isaura_2/2_isaura_H_0eX4h_L_0aX4c/VH/InitialRound/VHR02e_S12_L001_R1_001aafreq.txt
array3/mariajac/isaura_2/2_isaura_H_0eX4h_L_0aX4c_2/VH/InitialRound/VHR02e_S12_L001_R1_001aafreq.txt
array3/mariajac/isaura_2/2_isaura_H_0eX4h_L_0aX4d/VH/InitialRound/VHR02e_S12_L001_R1_001aafreq.txt
array3/mariajac/isaura_2/2_isaura_H_0eX4h_L_0bX4c/VH/InitialRound/VHR02e_S12_L001_R1_001aafreq.txt
array3/mariajac/isaura_2/2_isaura_H_0eX4h_L_0bX4d/VH/InitialRound/VHR02e_S12_L001_R1_001aafreq.txt
array3/mariajac/isaura_2/2_isaura_H_0eX4h_L_0bX4d_2/VH/InitialRound/VHR02e_S12_L001_R1_001aafreq.'''

b.count('\n')
# Out:
# 10

# %%
p = '/home/matheus/mcs/study/code/bioinfo/data/analysis'

a = pathlib.Path(p).rglob('*aafreq*')
n = 0 
for f in sorted(list(a)):
    if 'VH' in str(f) and 'isaura_2' in str(f).lower() and 'VHR0' in str(f):
        print(f)
        n += 1
        
print(n)
# Out:
# /home/matheus/mcs/study/code/bioinfo/data/analysis/array3/mariajac/isaura_2/2_isaura_H_0eX4g_L_0aX4c/VH/InitialRound/VHR02e_S12_L001_R1_001aafreq.txt
# /home/matheus/mcs/study/code/bioinfo/data/analysis/array3/mariajac/isaura_2/2_isaura_H_0eX4g_L_0aX4d/VH/InitialRound/VHR02e_S12_L001_R1_001aafreq.txt
# /home/matheus/mcs/study/code/bioinfo/data/analysis/array3/mariajac/isaura_2/2_isaura_H_0eX4g_L_0bX4c/VH/InitialRound/VHR02e_S12_L001_R1_001aafreq.txt
# /home/matheus/mcs/study/code/bioinfo/data/analysis/array3/mariajac/isaura_2/2_isaura_H_0eX4g_L_0bX4c_2/VH/InitialRound/VHR02e_S12_L001_R1_001aafreq.txt
# /home/matheus/mcs/study/code/bioinfo/data/analysis/array3/mariajac/isaura_2/2_isaura_H_0eX4g_L_0bX4d/VH/InitialRound/VHR02e_S12_L001_R1_001aafreq.txt
# /home/matheus/mcs/study/code/bioinfo/data/analysis/array3/mariajac/isaura_2/2_isaura_H_0eX4h_L_0aX4c/VH/InitialRound/VHR02e_S12_L001_R1_001aafreq.txt
# ...

# %%
f1= '/home/matheus/test/cdr/InitialRound_VHR02e_S12_L001_R1_001aafreq.csv'

vhr0_1 = pd.read_csv(f1)
vhr0_1.head()
# Out:
#          cdr3  quantity  length        MW      AV      IP    flex   gravy  \
# 0      FIVESK      5443       6  721.8413  0.1667  6.0014  0.7368  0.5500
# 1  DGVAVAGLDY      2463      10  979.0413  0.1000  3.5637  0.7231  0.6700
# 2    DLGIPDDY      1458       8  906.9324  0.1250  3.4228  0.7723 -0.6875
# 3      FLVESK      1133       6  721.8413  0.1667  6.0014  0.7423  0.4333
# 4     EMWGPEY      1096       7  910.9889  0.2857  3.7950  0.7594 -1.3286
#
#    SSF_Helix  SSF_Turn  ...  n_T  n_V  n_W  n_Y  aliphatic  aromatic  neutral  \
# 0     0.5000    0.1667  ...    0    1    0    0          2         1        1
# 1     0.4000    0.2000  ...    0    2    0    1          7         1        0
# 2     0.3750    0.2500  ...    0    0    0    1          4         1        0
# 3     0.5000    0.1667  ...    0    1    0    0          2         1        1
# 4     0.2857    0.2857  ...    0    0    1    1          3         2        0
#
#    positive  negative  invalid
# ...

# %%
p = '/home/matheus/mcs/study/code/bioinfo/data/analysis'

a = pathlib.Path(p).rglob('*aafreq*')
n = 0 
for f in sorted(list(a)):
    if 'VH' in str(f) and 'isaura_2' in str(f).lower() and 'VHR4' in str(f):
        print(f)
        n += 1
        
print(n)
# Out:
# /home/matheus/mcs/study/code/bioinfo/data/analysis/array3/mariajac/isaura_2/2_isaura_H_0eX4g_L_0aX4c/VH/FinalRound/VHR42g_S13_L001_R1_001aafreq.txt
# /home/matheus/mcs/study/code/bioinfo/data/analysis/array3/mariajac/isaura_2/2_isaura_H_0eX4g_L_0aX4d/VH/FinalRound/VHR42g_S13_L001_R1_001aafreq.txt
# /home/matheus/mcs/study/code/bioinfo/data/analysis/array3/mariajac/isaura_2/2_isaura_H_0eX4g_L_0bX4c/VH/FinalRound/VHR42g_S13_L001_R1_001aafreq.txt
# /home/matheus/mcs/study/code/bioinfo/data/analysis/array3/mariajac/isaura_2/2_isaura_H_0eX4g_L_0bX4c_2/VH/FinalRound/VHR42g_S13_L001_R1_001aafreq.txt
# /home/matheus/mcs/study/code/bioinfo/data/analysis/array3/mariajac/isaura_2/2_isaura_H_0eX4g_L_0bX4d/VH/FinalRound/VHR42g_S13_L001_R1_001aafreq.txt
# /home/matheus/mcs/study/code/bioinfo/data/analysis/array3/mariajac/isaura_2/2_isaura_H_0eX4h_L_0aX4c/VH/FinalRound/VHR42h_S14_L001_R1_001aafreq.txt
# ...

# %%
f2= '/home/matheus/test/cdr/FinalRound_VHR42g_S13_L001_R1_001aafreq.csv'

vhr0_2 = pd.read_csv(f2)
vhr0_2.head()
# Out:
#                cdr3  quantity  length         MW      AV      IP    flex  \
# 0        DGVAVAGLDY     14540      10   979.0413  0.1000  3.5637  0.7231
# 1            GRWGSY      1572       6   724.7640  0.3333  8.7476  0.7418
# 2  WGGGTEVVAAKGWFDP       420      16  1676.8247  0.1875  4.3703  0.7455
# 3  WEGGTEVVAAKGWFDP       344      16  1748.8874  0.1875  4.1374  0.7517
# 4            FLVESK       340       6   721.8413  0.1667  6.0014  0.7423
#
#     gravy  SSF_Helix  SSF_Turn  ...  n_T  n_V  n_W  n_Y  aliphatic  aromatic  \
# 0  0.6700     0.4000    0.2000  ...    0    2    0    1          7         1
# 1 -1.3833     0.3333    0.5000  ...    0    0    1    1          2         2
# 2 -0.1125     0.3125    0.3125  ...    1    2    2    0          9         3
# 3 -0.3063     0.3125    0.2500  ...    1    2    2    0          8         3
# 4  0.4333     0.5000    0.1667  ...    0    1    0    0          2         1
#
#    neutral  positive  negative  invalid
# ...

# %%
vhr0_1.head()
# Out:
#          cdr3  quantity  length        MW      AV      IP    flex   gravy  \
# 0      FIVESK      5443       6  721.8413  0.1667  6.0014  0.7368  0.5500
# 1  DGVAVAGLDY      2463      10  979.0413  0.1000  3.5637  0.7231  0.6700
# 2    DLGIPDDY      1458       8  906.9324  0.1250  3.4228  0.7723 -0.6875
# 3      FLVESK      1133       6  721.8413  0.1667  6.0014  0.7423  0.4333
# 4     EMWGPEY      1096       7  910.9889  0.2857  3.7950  0.7594 -1.3286
#
#    SSF_Helix  SSF_Turn  ...  n_T  n_V  n_W  n_Y  aliphatic  aromatic  neutral  \
# 0     0.5000    0.1667  ...    0    1    0    0          2         1        1
# 1     0.4000    0.2000  ...    0    2    0    1          7         1        0
# 2     0.3750    0.2500  ...    0    0    0    1          4         1        0
# 3     0.5000    0.1667  ...    0    1    0    0          2         1        1
# 4     0.2857    0.2857  ...    0    0    1    1          3         2        0
#
#    positive  negative  invalid
# ...

# %%
chart_f1 = alt.Chart(vhr0_1.iloc[:50]).mark_point().encode(
x = 'quantity',
y = 'length'
)

chart_f2 = alt.Chart(vhr0_2.iloc[:50]).mark_point().encode(
x = 'quantity',
y = 'length'
)

chart_f1 | chart_f2
# Out:
# <VegaLite 3 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
chart_f1 = alt.Chart(vhr0_1.iloc[:50]).mark_point().encode(
x = 'quantity',
y = 'aliphatic'
)

chart_f2 = alt.Chart(vhr0_2.iloc[:50]).mark_point().encode(
x = 'quantity',
y = 'aliphatic'
)

chart_f1 | chart_f2
# Out:
# <VegaLite 3 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
vhr0_2.head()
# Out:
#                cdr3  quantity  length         MW      AV      IP    flex  \
# 0        DGVAVAGLDY     14540      10   979.0413  0.1000  3.5637  0.7231
# 1            GRWGSY      1572       6   724.7640  0.3333  8.7476  0.7418
# 2  WGGGTEVVAAKGWFDP       420      16  1676.8247  0.1875  4.3703  0.7455
# 3  WEGGTEVVAAKGWFDP       344      16  1748.8874  0.1875  4.1374  0.7517
# 4            FLVESK       340       6   721.8413  0.1667  6.0014  0.7423
#
#     gravy  SSF_Helix  SSF_Turn  ...  n_T  n_V  n_W  n_Y  aliphatic  aromatic  \
# 0  0.6700     0.4000    0.2000  ...    0    2    0    1          7         1
# 1 -1.3833     0.3333    0.5000  ...    0    0    1    1          2         2
# 2 -0.1125     0.3125    0.3125  ...    1    2    2    0          9         3
# 3 -0.3063     0.3125    0.2500  ...    1    2    2    0          8         3
# 4  0.4333     0.5000    0.1667  ...    0    1    0    0          2         1
#
#    neutral  positive  negative  invalid
# ...

# %%
vhr0_2.tail()
# Out:
#                  cdr3  quantity  length         MW      AV      IP    flex  \
# 464  WEEETEVVAAKGWFDP         1      16  1893.0128  0.1875  3.9055  0.7642
# 465  GGGETKVVAAKGWFDP         1      16  1618.7871  0.1250  6.0690  0.7613
# 466  WGERTEVVAAKGWLDP         1      16  1814.0056  0.1250  4.6791  0.7557
# 467  WGGGTEVGAAKSWFDP         1      16  1664.7710  0.1875  4.3703  0.7607
# 468   WRGTEVVTAKGWFDP         1      15  1748.9338  0.2000  6.0698  0.7434
#
#       gravy  SSF_Helix  SSF_Turn  ...  n_T  n_V  n_W  n_Y  aliphatic  \
# 464 -0.6937     0.3125    0.1250  ...    1    2    2    0          6
# 465 -0.3000     0.2500    0.3125  ...    1    2    1    0          9
# 466 -0.5000     0.3125    0.1875  ...    1    2    2    0          8
# 467 -0.4250     0.2500    0.3750  ...    1    1    2    0          8
# 468 -0.5333     0.3333    0.2000  ...    2    2    2    0          6
#
#      aromatic  neutral  positive  negative  invalid
# ...

# %%
vhr0_1.head()
# Out:
#          cdr3  quantity  length        MW      AV      IP    flex   gravy  \
# 0      FIVESK      5443       6  721.8413  0.1667  6.0014  0.7368  0.5500
# 1  DGVAVAGLDY      2463      10  979.0413  0.1000  3.5637  0.7231  0.6700
# 2    DLGIPDDY      1458       8  906.9324  0.1250  3.4228  0.7723 -0.6875
# 3      FLVESK      1133       6  721.8413  0.1667  6.0014  0.7423  0.4333
# 4     EMWGPEY      1096       7  910.9889  0.2857  3.7950  0.7594 -1.3286
#
#    SSF_Helix  SSF_Turn  ...  n_T  n_V  n_W  n_Y  aliphatic  aromatic  neutral  \
# 0     0.5000    0.1667  ...    0    1    0    0          2         1        1
# 1     0.4000    0.2000  ...    0    2    0    1          7         1        0
# 2     0.3750    0.2500  ...    0    0    0    1          4         1        0
# 3     0.5000    0.1667  ...    0    1    0    0          2         1        1
# 4     0.2857    0.2857  ...    0    0    1    1          3         2        0
#
#    positive  negative  invalid
# ...

# %%
vhr0_1['quantity'].sum(axis=0, skipna=True)
# Out:
# 65089

# %%
vhr0_2['quantity'].sum(axis=0, skipna=True)
# Out:
# 21036

# %%
p2 = vhr0_2['quantity'].sum(axis=0, skipna=True)

# %%
vhr0_2.loc[0]['quantity']/p2
# Out:
# 0.6911960448754516

# %%
p1 = vhr0_1['quantity'].sum(axis=0, skipna=True)

# %%
vhr0_1.loc[0]['quantity']/p1
# Out:
# 0.0836239610379634

# %%
chart_f1 = alt.Chart(vhr0_1.iloc[:50]).mark_point().encode(
x = 'quantity',
y = 'aliphatic'
)

chart_f2 = alt.Chart(vhr0_2.iloc[:50]).mark_point().encode(
x = 'quantity',
y = 'aliphatic'
)

chart_f1 | chart_f2
# Out:
# <VegaLite 3 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
f3 = '/home/matheus/test/cdr/draft_R0_VH_S1_L001_R1_001aafreq.csv'

vhr0_3 = pd.read_csv(f3)
vhr0_3.head()
# Out:
#        cdr3  quantity  length        MW      AV      IP    flex   gravy  \
# 0    FIVESK     30123       6  721.8413  0.1667  6.0014  0.7368  0.5500
# 1  DLGIPDDY     10108       8  906.9324  0.1250  3.4228  0.7723 -0.6875
# 2   EMWGPEY      6600       7  910.9889  0.2857  3.7950  0.7594 -1.3286
# 3    FLVESK      4829       6  721.8413  0.1667  6.0014  0.7423  0.4333
# 4   EMWGPDY      3720       7  896.9623  0.2857  3.6660  0.7563 -1.3286
#
#    SSF_Helix  SSF_Turn  ...  n_T  n_V  n_W  n_Y  aliphatic  aromatic  neutral  \
# 0     0.5000    0.1667  ...    0    1    0    0          2         1        1
# 1     0.3750    0.2500  ...    0    0    0    1          4         1        0
# 2     0.2857    0.2857  ...    0    0    1    1          3         2        0
# 3     0.5000    0.1667  ...    0    1    0    0          2         1        1
# 4     0.2857    0.2857  ...    0    0    1    1          3         2        0
#
#    positive  negative  invalid
# 0         1         1        0
# ...

# %%
f4 = '/home/matheus/test/cdr/draft_R5b_VH_S10_L001_R1_001aafreq.csv'

vhr0_4 = pd.read_csv(f4)
vhr0_4.head()
# Out:
#      cdr3  quantity  length        MW      AV      IP    flex   gravy  \
# 0  FLVEVK    714166       6  733.8950  0.1667  6.0014  0.7018  1.2667
# 1  LLVEVK      2854       6  699.8788  0.0000  6.0014  0.7132  1.4333
# 2  FPVEVK      1511       6  717.8526  0.1667  6.0014  0.7378  0.3667
# 3  FLVEAK      1370       6  705.8419  0.1667  6.0014  0.7187  0.8667
# 4  FLAEVK      1267       6  705.8419  0.1667  6.0014  0.7187  0.8667
#
#    SSF_Helix  SSF_Turn  ...  n_T  n_V  n_W  n_Y  aliphatic  aromatic  neutral  \
# 0     0.6667    0.0000  ...    0    2    0    0          3         1        0
# 1     0.6667    0.0000  ...    0    2    0    0          4         0        0
# 2     0.5000    0.1667  ...    0    2    0    0          3         1        0
# 3     0.5000    0.0000  ...    0    1    0    0          3         1        0
# 4     0.5000    0.0000  ...    0    1    0    0          3         1        0
#
#    positive  negative  invalid
# 0         1         1        0
# ...

# %%
chart_f3 = alt.Chart(vhr0_3.iloc[:50]).mark_point().encode(
x = 'quantity',
y = 'aliphatic'
)

chart_f4 = alt.Chart(vhr0_4.iloc[:50]).mark_point().encode(
x = 'quantity',
y = 'aliphatic'
)

chart_f3 | chart_f4
# Out:
# <VegaLite 3 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
s3 = vhr0_3['quantity'].sum(axis=0, skipna=True)
p3 = vhr0_3.loc[0]['quantity']/s3

s4 = vhr0_4['quantity'].sum(axis=0, skipna=True)
p4 = vhr0_4.loc[0]['quantity']/s4


print(s3, s4)
print(p3, p4)
# Out:
# 380138 741606
# 0.0792422751737527 0.962999220610405

# %%
vhr0_3.loc[1]['quantity']
# Out:
# 10108
